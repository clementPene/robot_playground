# %%
# Exemple de visualisation de la trajectoire résultante dans Meshcat
if 'display' in locals():
    # Affichez la trajectoire de référence en rouge
    display.displayReference(x_traj, (1.0, 0.0, 0.0, 0.5))
    
    # Affichez la trajectoire optimisée
    display.display_xs(solver.xs)

# %%
import crocoddyl
import pinocchio as pin
import meshcat
import mujoco
print(crocoddyl.__version__)
print(pin.__version__)
print(mujoco.__version__)
# Out:
# 3.0.1
# 3.7.0
# 3.3.7

# %%
pin.buildModelsFromMJCF?
# Out:
# Signature: pin.buildModelsFromMJCF(filename, *args, **kwargs)
# Docstring:
# Parse the Mjcf file given in input and return a Pinocchio Model followed by corresponding GeometryModels of types specified by geometry_types, in the same order as listed.
# Arguments:
#     - filename - name of the urdf file to load
#     - package_dirs - where the meshes of the urdf are located. (default - None)
#     - root_joint - Joint at the base of the model (default - None)
#     - root_joint_name - Name for the root_joint (default - "root_joint")
#     - verbose - print information of parsing (default - False)
#     - meshLoader - object used to load meshes (default - hpp::fcl::MeshLoader)
#     - geometry_types - Which geometry model to load. Can be pin.GeometryType.COLLISION, pin.GeometryType.VISUAL or both. (default - [pin.GeometryType.COLLISION, pin.GeometryType.VISUAL])
#     - contacts - Boolean to know if contraint models are wanted (default - False)
# Return:
# ...

# %%
dir(crocoddyl)
# Out:
# ['ABC',
#  'ActionDataAbstract',
#  'ActionDataImpulseFwdDynamics',
#  'ActionDataLQR',
#  'ActionDataNumDiff',
#  'ActionDataUnicycle',
#  'ActionModelAbstract',
#  'ActionModelImpulseFwdDynamics',
#  'ActionModelLQR',
#  'ActionModelNumDiff',
#  'ActionModelUnicycle',
#  'ActivationBounds',
#  'ActivationDataAbstract',
#  'ActivationDataNumDiff',
#  'ActivationDataSmooth1Norm',
#  'ActivationModel2NormBarrier',
#  'ActivationModelAbstract',
#  'ActivationModelNumDiff',
#  'ActivationModelQuad',
#  'ActivationModelQuadFlatExp',
#  'ActivationModelQuadFlatLog',
#  'ActivationModelQuadraticBarrier',
#  'ActivationModelSmooth1Norm',
#  'ActivationModelSmooth2Norm',
#  'ActivationModelWeightedQuad',
#  'ActivationModelWeightedQuadraticBarrier',
#  'ActuationDataAbstract',
#  'ActuationModelAbstract',
#  'ActuationModelFloatingBase',
#  'ActuationModelFloatingBaseThrusters',
#  'ActuationModelFull',
#  'ActuationModelMultiCopterBase',
#  'ActuationSquashingData',
# ...

# %%
import robot_deploy
print(robot_deploy.__file__)
# Out:
# /home/cpene/Documents/robot_playground/.venv/lib/python3.12/site-packages/robot_deploy/__init__.py

# %%
from robot_deploy.simulators import MujocoSim
print(MujocoSim)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from robot_deploy.simulators import MujocoSim
#       2 print(MujocoSim)
#
# File ~/Documents/robot_playground/.venv/lib/python3.12/site-packages/robot_deploy/simulators/__init__.py:1
# ----> 1 from .sim_mujoco import MujocoSim
#       3 __all__ = ["MujocoSim"]
#
# File ~/Documents/robot_playground/.venv/lib/python3.12/site-packages/robot_deploy/simulators/sim_mujoco.py:9
#       6 import mujoco.viewer
#       8 from robot_assets import SCENE_PATHS
# ----> 9 from robot_deploy.input_devices import Button, InputDevice, MujocoDevice
#      10 from robot_deploy.utils.mj_logger import MJLogger
#      13 class ConfigError(Exception): ...
#
# File ~/Documents/robot_playground/.venv/lib/python3.12/site-packages/robot_deploy/input_devices/__init__.py:4
#       2 from .input_device import Button, InputDevice
# ...
